# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, GRU
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("finaldata.csv", index_col = False)
df = df.drop(["FractionalIncrease", "High", "Low", "Positive"],axis=1)
df = df.fillna(0)
x_train, x_test, y_train, y_test = train_test_split(df.drop(["Delta"], axis=1), df["Delta"], test_size=0.20, random_state=4)
x_train = x_train.values
x_test = x_test.values
y_train = y_train.values
y_test = y_test.values

# %%
# df['ReuterCredit'] = 1-df['ReuterCredit']
# df['InvestCredit'] = 1-df['InvestCredit']
# df['FoolCredit'] = 1-df['FoolCredit']
# df['CnbcCredit'] = 1-df['CnbcCredit']
# df['MarketCredit'] = 1-df['MarketCredit']
df
# Out:
#          Open   Delta  ReuterCredit  reuter_score  InvestCredit  invest_score  \
# 0     778.550  -4.060      0.973861      0.378063      0.976303      0.911567
# 1     792.950  14.400      0.949589      0.776000      0.931008      0.873125
# 2     817.360  24.410      0.945488      0.468813      0.937707      0.959300
# 3     809.100  -8.260      0.958241      0.093980      0.950460      0.982900
# 4     802.330  -6.770      0.968660      0.634683      0.957466      0.952050
# 5     807.500   5.170      0.971340      0.520433      0.961143      0.963560
# 6     828.380  20.880      0.951983      0.970550      0.950226      0.875420
# 7     829.000   0.620      0.958883      0.427571      0.957756      0.981425
# 8     859.050  30.050      0.955338      0.360867      0.949628      0.968350
# 9     815.000 -44.050      0.945884      0.240483      0.946424      0.988067
# 10    831.730  16.730      0.955978      0.446863      0.956641      0.978900
# 11    838.500   6.770      0.963086      0.688550      0.963630      0.921250
# 12    851.080  12.580      0.940775      0.115389      0.948204      0.938600
# 13    856.310   5.230      0.954243      0.881422      0.952601      0.604780
# 14    853.690  -2.620      0.961990      0.430812      0.962504      0.976400
# 15    870.530  16.840      0.960241      0.092762      0.959476      0.993720
# 16    841.390 -29.140      0.947872      0.463950      0.951744      0.991800
# 17    851.980  10.590      0.959188      0.956917      0.956075      0.741020
# 18    849.500  -2.480      0.969343      0.535957      0.964785      0.761230
# 19    841.040  -8.460      0.960976      0.090320      0.955182      0.802000
# 20    859.740  18.700      0.959337     -0.138700      0.960451      0.929357
# 21    890.000  30.260      0.954866      0.386140      0.956009      0.908040
# 22    950.290  60.290      0.949166      0.360056      0.949371      0.954340
# 23    951.290   1.000      0.962801      0.258529      0.963098      0.536350
# 24    943.200  -8.090      0.950732      0.000000      0.963361      0.972050
# 25    979.000  35.800      0.956565      0.000000      0.960496      0.981330
# 26    990.960  11.960      0.958818     -0.108480      0.957176      0.977680
# 27   1004.230  13.270      0.968058      0.483967      0.969697      0.952140
# 28    948.020 -56.210      0.964556      0.000000      0.967995      0.000000
# 29    976.870  28.850      0.949603      0.271027      0.955744      0.000000
# ..        ...     ...           ...           ...           ...           ...
# 270    51.614   0.900      0.959337      0.255711      0.960451      0.985750
# 271    53.396   1.782      0.954866      0.386987      0.956009      0.973533
# 272    54.490   1.094      0.949166      0.501822      0.949371      0.412600
# 273    53.515  -0.975      0.962801      0.792914      0.963098      0.987650
# 274    51.573  -1.942      0.950732      0.676843      0.963361      0.986500
# 275    52.499   0.926      0.956565      0.783140      0.960496      0.991800
# 276    50.803  -1.696      0.958818      0.323386      0.957176      0.989000
# 277    51.267   0.464      0.968058      0.516667      0.969697      0.993200
# 278    53.278   2.011      0.964556      0.360362      0.967995      0.983233
# 279    52.055  -1.223      0.949603      0.000000      0.955744      0.000000
# 280    54.866   2.811      0.958270      0.000000      0.963424      0.000000
# 281    55.190   0.324      0.959790      0.000000      0.965351      0.000000
# 282    54.480  -0.710      0.960305      0.000000      0.965747      0.000000
# 283    54.185  -0.295      0.960868      0.000000      0.965699      0.000000
# 284    54.086  -0.099      0.946547      0.000000      0.949770      0.000000
# 285    53.129  -0.957      0.948479      0.386709      0.951724      0.977900
# 286    52.027  -1.102      0.962293      0.696571      0.956636      0.990800
# 287    52.106   0.079      0.961899      0.413260      0.953633      0.000000
# 288    51.828  -0.278      0.969322      0.000000      0.955350      0.000000
# 289    50.646  -1.182      0.966850      0.000000      0.956300      0.897750
# 290    49.594  -1.052      0.965390      0.635550      0.958744      0.000000
# 291    51.182   1.588      0.972365      0.000000      0.962037      0.000000
# 292    53.178   1.996      0.969490      0.766350      0.958988      0.996400
# 293    53.913   0.735      0.969182      0.000000      0.958863      0.000000
# 294    54.618   0.705      0.962938      0.000000      0.954641      0.000000
# 295    55.304   0.686      0.964486      0.568378      0.956888      0.974100
# 296    52.742  -2.562      0.958474     -0.031333      0.951200      0.991600
# 297    55.065   2.323      0.952980      0.579650      0.948302      0.988600
# 298    55.800   0.735      0.955190      0.719950      0.958027      0.742700
# 299    53.900  -1.900      0.953194      0.792456      0.955969      0.812771
#
#      FoolCredit  fool_score  CnbcCredit  cnbc_score  MarketCredit  \
# 0      0.973861    0.996175    0.972168    0.970089      0.976303
# 1      0.945323    0.995257    0.947928    0.745560      0.947762
# 2      0.945956    0.988333    0.936020    0.936578      0.950255
# 3      0.953223    0.994040    0.958978    0.957580      0.959143
# 4      0.961919    0.992733    0.971298    0.985720      0.969111
# 5      0.970175    0.994886    0.971668    0.970120      0.973771
# 6      0.951400    0.975860    0.955913    0.707400      0.954343
# 7      0.958249    0.964033    0.961983    0.851680      0.960198
# 8      0.954678    0.980267    0.958023    0.317280      0.956130
# 9      0.945554    0.991900    0.948000    0.508890      0.946853
# 10     0.956926    0.986925    0.960243    0.935950      0.954948
# 11     0.963816    0.996500    0.965619    0.700422      0.962841
# 12     0.948296    0.921100    0.956183    0.631075      0.948267
# 13     0.958003    0.986660    0.960636    0.929763      0.958447
# 14     0.965206    0.997533    0.966522    0.862680      0.965886
# 15     0.964124    0.994725    0.963275    0.658450      0.964464
# 16     0.954068    0.996950    0.951714    0.796989      0.954238
# 17     0.963299    0.988350    0.963946    0.724320      0.963355
# 18     0.971398    0.997633    0.971722    0.691278      0.971426
# 19     0.958255    0.989286    0.960932    0.968690      0.960399
# 20     0.956677    0.994186    0.960873    0.698273      0.957749
# 21     0.953383    0.917800    0.956857    0.650780      0.953823
# 22     0.947716    0.919533    0.952700    0.508275      0.947839
# 23     0.962361    0.993600    0.964940    0.941630      0.951785
# 24     0.951233    0.000000    0.961402    0.000000      0.948821
# 25     0.954847    0.000000    0.958557    0.686456      0.953001
# 26     0.948091    0.000000    0.958740    0.000000      0.949841
# 27     0.961068    0.000000    0.967710    0.876300      0.964029
# 28     0.950700    0.997167    0.951791    0.418660      0.962946
# 29     0.943368    0.000000    0.945918    0.000000      0.950853
# ..          ...         ...         ...         ...           ...
# 270    0.956677    0.801800    0.960873    0.648233      0.957749
# 271    0.953383    0.990600    0.956857    0.650144      0.953823
# 272    0.947716    0.755100    0.952700    0.578188      0.947839
# 273    0.962361    0.982400    0.964940    0.730450      0.951785
# 274    0.951233    0.981525    0.961402    0.978920      0.948821
# 275    0.954847    0.997900    0.958557    0.730200      0.953001
# 276    0.948091    0.991525    0.958740    0.859586      0.949841
# 277    0.961068    0.864871    0.967710    0.707050      0.964029
# 278    0.950700    0.771422    0.951791    0.125167      0.962946
# 279    0.943368    0.000000    0.945918    0.000000      0.950853
# 280    0.954918    0.000000    0.955381    0.000000      0.958133
# 281    0.958114    0.000000    0.958077    0.000000      0.959721
# 282    0.959273    0.000000    0.961101    0.000000      0.961224
# 283    0.959329    0.000000    0.959571    0.000000      0.961453
# 284    0.946851    0.000000    0.945723    0.000000      0.946362
# 285    0.946802    0.673575    0.946181    0.274880      0.947571
# 286    0.963423    0.990688    0.952321    0.377650      0.961096
# 287    0.958427    0.000000    0.944220    0.000000      0.956918
# 288    0.966871    0.000000    0.959768    0.000000      0.963779
# 289    0.966084    0.926580    0.960220    0.168733      0.963164
# 290    0.967980    0.853040    0.961069    0.421600      0.964013
# 291    0.973388    0.000000    0.965885    0.000000      0.970031
# 292    0.971006    0.996520    0.963318    0.747840      0.968159
# 293    0.970561    0.000000    0.962886    0.000000      0.966774
# 294    0.966238    0.000000    0.958563    0.000000      0.960156
# 295    0.963984    0.970300    0.957854    0.316230      0.963772
# 296    0.955278    0.978710    0.951441    0.800910      0.958493
# 297    0.953636    0.985563    0.951669    0.807670      0.955261
# 298    0.959176    0.993040    0.954426    0.382500      0.950175
# 299    0.958033    0.995925    0.952466    0.839611      0.950854
#
#      market_score
# 0        0.974950
# 1        0.328733
# 2        0.000000
# 3        0.000000
# 4        0.990033
# 5        0.827050
# 6        0.572450
# 7        0.950140
# 8        0.595620
# 9        0.501175
# 10       0.361167
# 11       0.940867
# 12       0.875400
# 13       0.738167
# 14       0.989117
# 15       0.781950
# 16       0.708000
# 17       0.509040
# 18       0.037150
# 19       0.659317
# 20       0.496686
# 21       0.492467
# 22       0.547683
# 23       0.000000
# 24       0.970720
# 25       0.000000
# 26       0.977167
# 27       0.968262
# 28       0.000000
# 29       0.817040
# ..            ...
# 270      0.994100
# 271      0.979720
# 272      0.661886
# 273      0.992100
# 274      0.994050
# 275      0.981100
# 276      0.986575
# 277      0.931250
# 278      0.519233
# 279      0.000000
# 280      0.000000
# 281      0.000000
# 282      0.000000
# 283      0.000000
# 284      0.000000
# 285      0.655233
# 286      0.872740
# 287      0.000000
# 288      0.000000
# 289      0.127437
# 290      0.375300
# 291      0.000000
# 292      0.988100
# 293      0.000000
# 294      0.000000
# 295      0.418150
# 296      0.700157
# 297      0.959900
# 298      0.000000
# 299      0.960900
#
# [300 rows x 12 columns]

# %%
df_no_cred = df[["Open", "Delta", "reuter_score", "invest_score", "fool_score", "cnbc_score", "market_score"]].copy()

# %%
df_no_cred
xnc_train, xnc_test, ync_train, ync_test = train_test_split(df_no_cred.drop(["Delta"], axis=1), df_no_cred["Delta"], test_size=0.20, random_state=4)
xnc_train = xnc_train.values
xnc_test = xnc_test.values
ync_train = ync_train.values
ync_test = ync_test.values

# %%
model = Sequential()
model.add(Dense(512, input_dim=x_train.shape[1], activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='linear'))

adam = Adam(lr=0.1)
model.compile(loss='mean_squared_error',
 optimizer='adam',
 metrics=['mse'])

# %%
history = model.fit(x_train, y_train,
 batch_size=128,
 epochs=10000,
 verbose=0,
 validation_split=0.1)

# %%
modelnc = Sequential()
modelnc.add(Dense(512, input_dim=xnc_train.shape[1], activation='relu'))
modelnc.add(Dense(256, activation='relu'))
modelnc.add(Dense(128, activation='relu'))
modelnc.add(Dense(1, activation='linear'))


adam = Adam(lr=0.1)
modelnc.compile(loss='mean_squared_error',
 optimizer='adam',
 metrics=['mse'])

# %%
historync = modelnc.fit(xnc_train, ync_train,
 batch_size=128,
 epochs=10000,
 verbose=0,
 validation_split=0.1)

# %%
fig = plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
fig.savefig("deltaloss.png")

# %%
fig = plt.figure()
plt.plot(y_test)
plt.plot(model.predict(x_test))
plt.plot(modelnc.predict(xnc_test))
plt.title('prediction w/ nc vs prediction w/o nc vs actual')
plt.ylabel('delta')
plt.legend(['actual', 'prediction w/ nc', 'prediction w/o nc'], loc='upper left')
plt.show()

fig.savefig("deltaincrease.png")

# %%
score = model.evaluate(x_test, y_test, verbose=0)

# %%
score
# Out:
# [87.12587992350261, 87.12587992350261]

# %%
scorenc = modelnc.evaluate(xnc_test, ync_test, verbose=0)

# %%
scorenc
# Out:
# [128.02448628743488, 128.02448628743488]

# %%
values = model.predict(x_test)

# %%
binary_score = 0
for i in range(len(values)):
    if (values[i] > 0 and y_test[i] > 0):
        binary_score += 1
    elif(values[i] < 0 and y_test[i] < 0):
        binary_score += 1

# %%
binary_score, len(values)
# Out:
# (37, 60)

# %%
valuesnc = modelnc.predict(xnc_test)

# %%
binary_scorenc = 0
for i in range(len(values)):
    if (valuesnc[i] > 0 and ync_test[i] > 0):
        binary_scorenc += 1
    elif(valuesnc[i] < 0 and ync_test[i] < 0):
        binary_scorenc += 1

# %%
binary_scorenc, len(valuesnc)
# Out:
# (27, 60)
