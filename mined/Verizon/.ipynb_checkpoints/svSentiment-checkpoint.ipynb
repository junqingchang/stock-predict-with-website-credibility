# %%
import nltk
from nltk.corpus import stopwords
from string import punctuation
from os import listdir
import pandas as pd
from collections import Counter
import numpy as np
import string
nltk.downloader.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zenger/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# /anaconda3/lib/python3.7/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
import glob
folderName = 'verizon'
files = listdir()
print(files)
df = pd.concat([pd.read_csv(f) for f in glob.glob('*.csv')], ignore_index = True)
# Out:
# ['.DS_Store', 'Verizon CommunicationsBonus.csv', 'svSentiment.ipynb', 'Verizon Communications4.csv', 'Verizon Communications5.csv', 'Verizon Communications6.csv', 'Verizon Communications2.csv', 'Verizon Communications3.csv', 'Verizon Communications1.csv', '.ipynb_checkpoints']

# %%
def fix_csv(dataframe):
    pd.set_option('display.max_rows',20)
    pd.set_option('display.max_columns',10)
    dataframe['sv_score'] = 0.0
    dataframe = dataframe.dropna(subset = ['Text'])
    return dataframe

# %%
df = fix_csv(df)

# %%
df
# Out:
#                    Author   EndDate          Site  StartDate  \
# 0                     NaN  12082016       Reuters   12012016
# 1                     NaN  12082016       Reuters   12012016
# 2                     NaN  12082016       Reuters   12012016
# 3        Giovanny Moreano  12082016          CNBC   12012016
# 4                 Tae Kim  12082016          CNBC   12012016
# 5        Giovanny Moreano  12082016          CNBC   12012016
# 6                 Tae Kim  12082016          CNBC   12012016
# 7             John Melloy  12082016          CNBC   12012016
# 8        Giovanny Moreano  12082016          CNBC   12012016
# 9                 Tae Kim  12082016          CNBC   12012016
# ..                    ...       ...           ...        ...
# 943        Donna Fuscaldo   2092017  Investopedia    2022017
# 944        Donna Fuscaldo   2092017  Investopedia    2022017
# 945           Fred Imbert   2092017          CNBC    2022017
# 946               Tae Kim   2092017          CNBC    2022017
# 947               Tae Kim   2092017          CNBC    2022017
# 948         Jennifer Saba   2092017          CNBC    2022017
# 949         Andrew Tonner   2092017          Fool    2022017
# 950         Brian Feroldi   2092017          Fool    2022017
# 951  Matthew Frankel, CFP   2092017          Fool    2022017
# 952                   NaN   2092017   MarketWatch    2022017
#
#                                                   Text  \
# 0    The data centers being sold are located in 15 ...
# 1    NEW YORK (Reuters) - Two of Asia’s biggest tec...
# 2    根据华尔街日报，这些投资资金将来自一规模为1千亿美元的投资基金，软银社长孙正义正与沙特主权财...
# 3    Guggenheim on Thursday advised clients to buy ...
# 4    Cowen lowered its rating for Nike shares to ma...
# 5    An era of wearing athletic apparel in public m...
# 6    Credit Suisse lowered its rating for Kellogg s...
# 7    There is one major, well-informed group of ind...
# 8    Jason Helfstein of Oppenheimer upgraded Pandor...
# 9    Investors should buy McDonald's on the growth ...
# ..                                                 ...
# 943  Find the best broker for your trading or inves...
# 944  Find the best broker for your trading or inves...
# 945  The Dow Jones industrial average is off to a s...
# 946  Investors should buy Caterpillar shares becaus...
# 947  Investors should buy FedEx shares because its ...
# 948  Bob Iger may swing for a three-peat. The Walt ...
# 949  Founded in 1993 by brothers Tom and David Gard...
# 950  Founded in 1993 by brothers Tom and David Gard...
# 951  Founded in 1993 by brothers Tom and David Gard...
# 952  Published: Feb 9, 2017 9:02 a.m. ET VALLEY COT...
#
#                                                  Title  sv_score
# 0    \r\n                Verizon to sell data cente...       0.0
# 1    \r\n                SoftBank's Son pledges $50...       0.0
# 2    \r\n                焦点：日本软银将在美国投资500亿美元 给特朗普送上...       0.0
# 3    Trump's tax cuts to boost shares of Olive Gard...       0.0
# 4    Cowen downgrades Nike on market losses to Unde...       0.0
# 5    A shift in fashion from 'athleisure to denim' ...       0.0
# 6    Kellogg can't get millennials to buy enough ce...       0.0
# 7    One really important group is not buying durin...       0.0
# 8    Pandora could fetch as much as $21 a share in ...       0.0
# 9    Buy McDonald's on new burger launches in 2017,...       0.0
# ..                                                 ...       ...
# 943  Charter Passing on Broadcast Fee to New Custom...       0.0
# 944  Morningstar: Comcast Overvalued at Current Lev...       0.0
# 945  Four stocks are responsible for the Dow's gain...       0.0
# 946  Caterpillar to rally nearly 20 percent on mini...       0.0
# 947  Monster rally in FedEx could continue as globa...       0.0
# 948  Breakingviews: Disney boss risks overstaying h...       0.0
# 949  \r\n      \r\n    2 Stocks Projected to Grow P...       0.0
# 950  \r\n      \r\n    3 of the Highest-Growth Stoc...       0.0
# 951  \r\n      \r\n    Better Buy: Vanguard High Di...       0.0
# 952  Global B2B Telecommunications Market to Witnes...       0.0
#
# [950 rows x 7 columns]

# %%
def sentiment_Col(df):
    sid = SentimentIntensityAnalyzer()
    for index,row in df.iterrows():
        text = row['Text']
        stop_words = set(stopwords.words('english'))
        word_tokens = word_tokenize(text)
        filtered_sentence = [word for word in word_tokens if word.isalpha()]
        filtered_sentence = [w for w in filtered_sentence if not w in stop_words]
        filtered_sentence = [word for word in filtered_sentence if len(word)>1]
        final_sentence = []
        for w in filtered_sentence:
            final_sentence.append(w)
        final_sentence = TreebankWordDetokenizer().detokenize(final_sentence)
        cmp_Score = sid.polarity_scores(final_sentence)['compound']
        df.at[index,'sv_score'] = cmp_Score
    return df

# %%
sentiment_Col(df)
# Out:
#                    Author   EndDate          Site  StartDate  \
# 0                     NaN  12082016       Reuters   12012016
# 1                     NaN  12082016       Reuters   12012016
# 2                     NaN  12082016       Reuters   12012016
# 3        Giovanny Moreano  12082016          CNBC   12012016
# 4                 Tae Kim  12082016          CNBC   12012016
# 5        Giovanny Moreano  12082016          CNBC   12012016
# 6                 Tae Kim  12082016          CNBC   12012016
# 7             John Melloy  12082016          CNBC   12012016
# 8        Giovanny Moreano  12082016          CNBC   12012016
# 9                 Tae Kim  12082016          CNBC   12012016
# ..                    ...       ...           ...        ...
# 943        Donna Fuscaldo   2092017  Investopedia    2022017
# 944        Donna Fuscaldo   2092017  Investopedia    2022017
# 945           Fred Imbert   2092017          CNBC    2022017
# 946               Tae Kim   2092017          CNBC    2022017
# 947               Tae Kim   2092017          CNBC    2022017
# 948         Jennifer Saba   2092017          CNBC    2022017
# 949         Andrew Tonner   2092017          Fool    2022017
# 950         Brian Feroldi   2092017          Fool    2022017
# 951  Matthew Frankel, CFP   2092017          Fool    2022017
# 952                   NaN   2092017   MarketWatch    2022017
#
#                                                   Text  \
# 0    The data centers being sold are located in 15 ...
# 1    NEW YORK (Reuters) - Two of Asia’s biggest tec...
# 2    根据华尔街日报，这些投资资金将来自一规模为1千亿美元的投资基金，软银社长孙正义正与沙特主权财...
# 3    Guggenheim on Thursday advised clients to buy ...
# 4    Cowen lowered its rating for Nike shares to ma...
# 5    An era of wearing athletic apparel in public m...
# 6    Credit Suisse lowered its rating for Kellogg s...
# 7    There is one major, well-informed group of ind...
# 8    Jason Helfstein of Oppenheimer upgraded Pandor...
# 9    Investors should buy McDonald's on the growth ...
# ..                                                 ...
# 943  Find the best broker for your trading or inves...
# 944  Find the best broker for your trading or inves...
# 945  The Dow Jones industrial average is off to a s...
# 946  Investors should buy Caterpillar shares becaus...
# 947  Investors should buy FedEx shares because its ...
# 948  Bob Iger may swing for a three-peat. The Walt ...
# 949  Founded in 1993 by brothers Tom and David Gard...
# 950  Founded in 1993 by brothers Tom and David Gard...
# 951  Founded in 1993 by brothers Tom and David Gard...
# 952  Published: Feb 9, 2017 9:02 a.m. ET VALLEY COT...
#
#                                                  Title  sv_score
# 0    \r\n                Verizon to sell data cente...    0.9001
# 1    \r\n                SoftBank's Son pledges $50...    0.9744
# 2    \r\n                焦点：日本软银将在美国投资500亿美元 给特朗普送上...    0.0000
# 3    Trump's tax cuts to boost shares of Olive Gard...    0.9584
# 4    Cowen downgrades Nike on market losses to Unde...    0.0258
# 5    A shift in fashion from 'athleisure to denim' ...    0.6124
# 6    Kellogg can't get millennials to buy enough ce...    0.5859
# 7    One really important group is not buying durin...    0.9229
# 8    Pandora could fetch as much as $21 a share in ...    0.7269
# 9    Buy McDonald's on new burger launches in 2017,...    0.9287
# ..                                                 ...       ...
# 943  Charter Passing on Broadcast Fee to New Custom...   -0.9432
# 944  Morningstar: Comcast Overvalued at Current Lev...    0.9783
# 945  Four stocks are responsible for the Dow's gain...    0.9022
# 946  Caterpillar to rally nearly 20 percent on mini...    0.7430
# 947  Monster rally in FedEx could continue as globa...    0.8555
# 948  Breakingviews: Disney boss risks overstaying h...    0.3400
# 949  \r\n      \r\n    2 Stocks Projected to Grow P...    0.9983
# 950  \r\n      \r\n    3 of the Highest-Growth Stoc...    0.9984
# 951  \r\n      \r\n    Better Buy: Vanguard High Di...    0.9906
# 952  Global B2B Telecommunications Market to Witnes...    0.9967
#
# [950 rows x 7 columns]

# %%
df.to_csv('{}Processed.csv'.format(folderName))
