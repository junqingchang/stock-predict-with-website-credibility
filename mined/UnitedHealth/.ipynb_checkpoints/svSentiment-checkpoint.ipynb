# %%
import nltk
from nltk.corpus import stopwords
from string import punctuation
from os import listdir
import pandas as pd
from collections import Counter
import numpy as np
import string
nltk.downloader.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zenger/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# /anaconda3/lib/python3.7/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
import glob
folderName = 'unitedhealth'
files = listdir()
print(files)
df = pd.concat([pd.read_csv(f) for f in glob.glob('*.csv')], ignore_index = True)
# Out:
# ['.DS_Store', 'United Health Group16.csv', 'United Health Group15.csv', 'svSentiment.ipynb', '.ipynb_checkpoints']

# %%
def fix_csv(dataframe):
    pd.set_option('display.max_rows',20)
    pd.set_option('display.max_columns',10)
    dataframe['sv_score'] = 0.0
    dataframe = dataframe.dropna(subset = ['Text'])
    return dataframe

# %%
df = fix_csv(df)

# %%
df
# Out:
#                 Author  EndDate         Site  StartDate  \
# 0                       8312017      Reuters    8242017
# 1                       8312017      Reuters    8242017
# 2                       8312017      Reuters    8242017
# 3                       8312017      Reuters    8242017
# 4                       8312017      Reuters    8242017
# 5                       8312017      Reuters    8242017
# 6                       8312017      Reuters    8242017
# 7                       8312017      Reuters    8242017
# 8                       8312017      Reuters    8242017
# 9                       8312017      Reuters    8242017
# ..                 ...      ...          ...        ...
# 556      Sean Williams  8242017         Fool    8172017
# 557      Brian Feroldi  8242017         Fool    8172017
# 558      Todd Campbell  8242017         Fool    8172017
# 559      Todd Campbell  8242017         Fool    8172017
# 560   Philip van Doorn  8242017  MarketWatch    8172017
# 561   Michael Ashbaugh  8242017  MarketWatch    8172017
# 562          Sue Chang  8242017  MarketWatch    8172017
# 563      Chris Edelson  8242017  MarketWatch    8172017
# 564      Chris Edelson  8242017  MarketWatch    8172017
# 565  Barbara Kollmeyer  8242017  MarketWatch    8172017
#
#                                                   Text  \
# 0    You don't have permission to access /advisory-...
# 1    (Reuters) - Advisory Board Co said it would se...
# 2    NEW YORK (Reuters) - Ohio’s Department of Insu...
# 3    ZURICH (Reuters) - Novartis’s new gene-modifyi...
# 4    NEW DELHI (Reuters) - India has been investiga...
# 5    TORONTO (Reuters) - As an influx of asylum see...
# 6    KAMPALA (Reuters) - United Nations peacekeeper...
# 7    The move, announced on Thursday, follows the c...
# 8    In response to the outbreak, the U.N. has open...
# 9    MAIDUGURI, Nigeria (Reuters) - Cholera has bro...
# ..                                                 ...
# 556  Founded in 1993 by brothers Tom and David Gard...
# 557  Founded in 1993 by brothers Tom and David Gard...
# 558  Founded in 1993 by brothers Tom and David Gard...
# 559  Founded in 1993 by brothers Tom and David Gard...
# 560  Published: Aug 18, 2017 7:21 a.m. ET Investors...
# 561  Published: Aug 22, 2017 1:18 p.m. ET Focus: Su...
# 562  Published: Aug 17, 2017 4:38 p.m. ET Dow drops...
# 563  Published: Aug 24, 2017 11:58 a.m. ET U.S. bus...
# 564  Men’s basketball teams from Oregon State, Clem...
# 565  Published: Aug 17, 2017 4:27 p.m. ET Officials...
#
#                                                  Title  sv_score
# 0                                        403 Forbidden       0.0
# 1    \r\n                Advisory Board to sell hea...       0.0
# 2    \r\n                Last 'bare county' in U.S....       0.0
# 3    \r\n                Profit on $475,000 Novarti...       0.0
# 4    \r\n                Exclusive: Bloomberg chari...       0.0
# 5    \r\n                Canada ramps up deportatio...       0.0
# 6    \r\n                U.N. moves to protect Sout...       0.0
# 7    \r\n                BAT restructures to help e...       0.0
# 8    Cholera Outbreak: 14 Dead, 230 Admitted In Bor...       0.0
# 9    \r\n                Cholera hits camp for disp...       0.0
# ..                                                 ...       ...
# 556  \r\n      \r\n    3 Reasons Obamacare Premiums...       0.0
# 557  \r\n      \r\n    Up 187% in 2017, Is Exact Sc...       0.0
# 558  \r\n      \r\n    Boy, Were We Wrong About Rit...       0.0
# 559  \r\n      \r\n    Is Regeneron Pharmaceuticals...       0.0
# 560  Nvidia, Facebook and 13 other companies are th...       0.0
# 561  Charting a corrective bounce, S&P 500 rallies ...       0.0
# 562  Stock market closes sharply lower as tech shar...       0.0
# 563  Why it’s time for CEOs to tell Trump: ‘You’re ...       0.0
# 564  Multiple U.S. men’s college basketball teams a...       0.0
# 565  Barcelona truck attack reportedly leaves at le...       0.0
#
# [559 rows x 7 columns]

# %%
def sentiment_Col(df):
    sid = SentimentIntensityAnalyzer()
    for index,row in df.iterrows():
        text = row['Text']
        stop_words = set(stopwords.words('english'))
        word_tokens = word_tokenize(text)
        filtered_sentence = [word for word in word_tokens if word.isalpha()]
        filtered_sentence = [w for w in filtered_sentence if not w in stop_words]
        filtered_sentence = [word for word in filtered_sentence if len(word)>1]
        final_sentence = []
        for w in filtered_sentence:
            final_sentence.append(w)
        final_sentence = TreebankWordDetokenizer().detokenize(final_sentence)
        cmp_Score = sid.polarity_scores(final_sentence)['compound']
        df.at[index,'sv_score'] = cmp_Score
    return df

# %%
sentiment_Col(df)
# Out:
#                 Author  EndDate         Site  StartDate  \
# 0                       8312017      Reuters    8242017
# 1                       8312017      Reuters    8242017
# 2                       8312017      Reuters    8242017
# 3                       8312017      Reuters    8242017
# 4                       8312017      Reuters    8242017
# 5                       8312017      Reuters    8242017
# 6                       8312017      Reuters    8242017
# 7                       8312017      Reuters    8242017
# 8                       8312017      Reuters    8242017
# 9                       8312017      Reuters    8242017
# ..                 ...      ...          ...        ...
# 556      Sean Williams  8242017         Fool    8172017
# 557      Brian Feroldi  8242017         Fool    8172017
# 558      Todd Campbell  8242017         Fool    8172017
# 559      Todd Campbell  8242017         Fool    8172017
# 560   Philip van Doorn  8242017  MarketWatch    8172017
# 561   Michael Ashbaugh  8242017  MarketWatch    8172017
# 562          Sue Chang  8242017  MarketWatch    8172017
# 563      Chris Edelson  8242017  MarketWatch    8172017
# 564      Chris Edelson  8242017  MarketWatch    8172017
# 565  Barbara Kollmeyer  8242017  MarketWatch    8172017
#
#                                                   Text  \
# 0    You don't have permission to access /advisory-...
# 1    (Reuters) - Advisory Board Co said it would se...
# 2    NEW YORK (Reuters) - Ohio’s Department of Insu...
# 3    ZURICH (Reuters) - Novartis’s new gene-modifyi...
# 4    NEW DELHI (Reuters) - India has been investiga...
# 5    TORONTO (Reuters) - As an influx of asylum see...
# 6    KAMPALA (Reuters) - United Nations peacekeeper...
# 7    The move, announced on Thursday, follows the c...
# 8    In response to the outbreak, the U.N. has open...
# 9    MAIDUGURI, Nigeria (Reuters) - Cholera has bro...
# ..                                                 ...
# 556  Founded in 1993 by brothers Tom and David Gard...
# 557  Founded in 1993 by brothers Tom and David Gard...
# 558  Founded in 1993 by brothers Tom and David Gard...
# 559  Founded in 1993 by brothers Tom and David Gard...
# 560  Published: Aug 18, 2017 7:21 a.m. ET Investors...
# 561  Published: Aug 22, 2017 1:18 p.m. ET Focus: Su...
# 562  Published: Aug 17, 2017 4:38 p.m. ET Dow drops...
# 563  Published: Aug 24, 2017 11:58 a.m. ET U.S. bus...
# 564  Men’s basketball teams from Oregon State, Clem...
# 565  Published: Aug 17, 2017 4:27 p.m. ET Officials...
#
#                                                  Title  sv_score
# 0                                        403 Forbidden   -0.6705
# 1    \r\n                Advisory Board to sell hea...    0.9771
# 2    \r\n                Last 'bare county' in U.S....    0.8225
# 3    \r\n                Profit on $475,000 Novarti...   -0.9509
# 4    \r\n                Exclusive: Bloomberg chari...    0.9758
# 5    \r\n                Canada ramps up deportatio...   -0.5423
# 6    \r\n                U.N. moves to protect Sout...   -0.9919
# 7    \r\n                BAT restructures to help e...    0.9869
# 8    Cholera Outbreak: 14 Dead, 230 Admitted In Bor...   -0.2960
# 9    \r\n                Cholera hits camp for disp...   -0.9794
# ..                                                 ...       ...
# 556  \r\n      \r\n    3 Reasons Obamacare Premiums...    0.9882
# 557  \r\n      \r\n    Up 187% in 2017, Is Exact Sc...    0.9759
# 558  \r\n      \r\n    Boy, Were We Wrong About Rit...    0.9995
# 559  \r\n      \r\n    Is Regeneron Pharmaceuticals...    0.9999
# 560  Nvidia, Facebook and 13 other companies are th...    0.9577
# 561  Charting a corrective bounce, S&P 500 rallies ...    0.9956
# 562  Stock market closes sharply lower as tech shar...   -0.9810
# 563  Why it’s time for CEOs to tell Trump: ‘You’re ...    0.9584
# 564  Multiple U.S. men’s college basketball teams a...   -0.9612
# 565  Barcelona truck attack reportedly leaves at le...   -0.9981
#
# [559 rows x 7 columns]

# %%
df.to_csv('{}Processed.csv'.format(folderName))
