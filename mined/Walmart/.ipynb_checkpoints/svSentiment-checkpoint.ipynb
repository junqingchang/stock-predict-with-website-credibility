# %%
import nltk
from nltk.corpus import stopwords
from string import punctuation
from os import listdir
import pandas as pd
from collections import Counter
import numpy as np
import string
nltk.downloader.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/zenger/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# /anaconda3/lib/python3.7/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
import glob
folderName = 'walmart'
files = listdir()
print(files)
df = pd.concat([pd.read_csv(f) for f in glob.glob('*.csv')], ignore_index = True)
# Out:
# ['Walmart14.csv', 'Walmart15.csv', 'Walmart17.csv', 'Walmart16.csv', 'Walmart12.csv', '.DS_Store', 'Walmart13.csv', 'svSentiment.ipynb', '.ipynb_checkpoints']

# %%
def fix_csv(dataframe):
    pd.set_option('display.max_rows',20)
    pd.set_option('display.max_columns',10)
    dataframe['sv_score'] = 0.0
    dataframe = dataframe.dropna(subset = ['Text'])
    return dataframe

# %%
df = fix_csv(df)

# %%
df
# Out:
#                                            Author  EndDate          Site  \
# 0                                             NaN  4132017       Reuters
# 1                                             NaN  4132017       Reuters
# 2                                             NaN  4132017       Reuters
# 3                                             NaN  4132017       Reuters
# 4                                             NaN  4132017       Reuters
# 5                                             NaN  4132017       Reuters
# 6                                    Investopedia  4132017  Investopedia
# 7                              Krystina Gustafson  4132017          CNBC
# 8                              Krystina Gustafson  4132017          CNBC
# 9                                   Lauren Thomas  4132017          CNBC
# ...                                           ...      ...           ...
# 1149                              Daniel B. Kline  4062017          Fool
# 1150                              Daniel B. Kline  4062017          Fool
# 1151                                Jeremy Bowman  4062017          Fool
# 1152                                Jeremy Bowman  4062017          Fool
# 1153                                 Travis Hoium  4062017          Fool
# 1154  Keith Noonan, Jason Hall, and Dan Caplinger  4062017          Fool
# 1155                                Jeremy Bowman  4062017          Fool
# 1156                                      Leo Sun  4062017          Fool
# 1157                                Mitch Tuchman  4062017   MarketWatch
# 1158                                  Sara Sjolin  4062017   MarketWatch
#
#       StartDate                                               Text  \
# 0       4062017  Wal-Mart confirmed the latest round of job cut...
# 1       4062017  * Aeon to cut prices for over 250 food, daily ...
# 2       4062017  WELLINGTON/SYDNEY (Reuters) - As China’s middl...
# 3       4062017  WASHINGTON (Reuters) - President Donald Trump ...
# 4       4062017  SAN FRANCISCO (Reuters) - A sophisticated hack...
# 5       4062017  ［ワシントン　１１日　ロイター］ - トランプ米大統領は１１日、財界首脳を招いたホワイトハウ...
# 6       4062017  Find the best broker for your trading or inves...
# 7       4062017  Wal-Mart is eliminating hundreds of jobs in it...
# 8       4062017  When it comes to where Americans like to shop,...
# 9       4062017  Amazon can't and won't stop growing, according...
# ...         ...                                                ...
# 1149    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1150    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1151    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1152    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1153    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1154    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1155    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1156    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1157    3302017  Published: Apr 1, 2017 11:30 a.m. ET Investing...
# 1158    3302017  Published: Apr 6, 2017 6:25 a.m. ET Hint: It’s...
#
#                                                   Title  sv_score
# 0     \r\n                Wal-Mart eliminates more c...       0.0
# 1     \r\n                Japanese retailer Aeon pla...       0.0
# 2     \r\n                Food fight: To beat China ...       0.0
# 3     \r\n                Trump's message to bankers...       0.0
# 4     \r\n                U.S. trade group hacked wi...       0.0
# 5     \r\n                トランプ米大統領、金融規制改革法改正を再表明　財界と...       0.0
# 6     Target and Bed Bath and Beyond Could Be Due fo...       0.0
# 7     Wal-Mart reportedly cutting hundreds of jobs t...       0.0
# 8     Nearly every American spent money at Wal-Mart ...       0.0
# 9     Amazon stock upgraded on its Prime program, gr...       0.0
# ...                                                 ...       ...
# 1149  \r\n      \r\n    Better Buy: Wal-Mart Stores ...       0.0
# 1150  \r\n      \r\n    These 8 Retailers Are Actual...       0.0
# 1151  \r\n      \r\n    Amazon Fresh Pickup Is a Tou...       0.0
# 1152  \r\n      \r\n    Why Amazon Is So Focused on ...       0.0
# 1153  \r\n      \r\n    The King of Beers Joins the ...       0.0
# 1154  \r\n      \r\n    The Next Stock Warren Buffet...       0.0
# 1155  \r\n      \r\n    After Souq.com Purchase, Wil...       0.0
# 1156  \r\n      \r\n    Is Amazon Following Microsof...       0.0
# 1157  Yale fund chief reveals truth about hedge fund...       0.0
# 1158  Here’s Draghi’s 4-point checklist for when it’...       0.0
#
# [1151 rows x 7 columns]

# %%
def sentiment_Col(df):
    sid = SentimentIntensityAnalyzer()
    for index,row in df.iterrows():
        text = row['Text']
        stop_words = set(stopwords.words('english'))
        word_tokens = word_tokenize(text)
        filtered_sentence = [word for word in word_tokens if word.isalpha()]
        filtered_sentence = [w for w in filtered_sentence if not w in stop_words]
        filtered_sentence = [word for word in filtered_sentence if len(word)>1]
        final_sentence = []
        for w in filtered_sentence:
            final_sentence.append(w)
        final_sentence = TreebankWordDetokenizer().detokenize(final_sentence)
        cmp_Score = sid.polarity_scores(final_sentence)['compound']
        df.at[index,'sv_score'] = cmp_Score
    return df

# %%
sentiment_Col(df)
# Out:
#                                            Author  EndDate          Site  \
# 0                                             NaN  4132017       Reuters
# 1                                             NaN  4132017       Reuters
# 2                                             NaN  4132017       Reuters
# 3                                             NaN  4132017       Reuters
# 4                                             NaN  4132017       Reuters
# 5                                             NaN  4132017       Reuters
# 6                                    Investopedia  4132017  Investopedia
# 7                              Krystina Gustafson  4132017          CNBC
# 8                              Krystina Gustafson  4132017          CNBC
# 9                                   Lauren Thomas  4132017          CNBC
# ...                                           ...      ...           ...
# 1149                              Daniel B. Kline  4062017          Fool
# 1150                              Daniel B. Kline  4062017          Fool
# 1151                                Jeremy Bowman  4062017          Fool
# 1152                                Jeremy Bowman  4062017          Fool
# 1153                                 Travis Hoium  4062017          Fool
# 1154  Keith Noonan, Jason Hall, and Dan Caplinger  4062017          Fool
# 1155                                Jeremy Bowman  4062017          Fool
# 1156                                      Leo Sun  4062017          Fool
# 1157                                Mitch Tuchman  4062017   MarketWatch
# 1158                                  Sara Sjolin  4062017   MarketWatch
#
#       StartDate                                               Text  \
# 0       4062017  Wal-Mart confirmed the latest round of job cut...
# 1       4062017  * Aeon to cut prices for over 250 food, daily ...
# 2       4062017  WELLINGTON/SYDNEY (Reuters) - As China’s middl...
# 3       4062017  WASHINGTON (Reuters) - President Donald Trump ...
# 4       4062017  SAN FRANCISCO (Reuters) - A sophisticated hack...
# 5       4062017  ［ワシントン　１１日　ロイター］ - トランプ米大統領は１１日、財界首脳を招いたホワイトハウ...
# 6       4062017  Find the best broker for your trading or inves...
# 7       4062017  Wal-Mart is eliminating hundreds of jobs in it...
# 8       4062017  When it comes to where Americans like to shop,...
# 9       4062017  Amazon can't and won't stop growing, according...
# ...         ...                                                ...
# 1149    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1150    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1151    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1152    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1153    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1154    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1155    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1156    3302017  Founded in 1993 by brothers Tom and David Gard...
# 1157    3302017  Published: Apr 1, 2017 11:30 a.m. ET Investing...
# 1158    3302017  Published: Apr 6, 2017 6:25 a.m. ET Hint: It’s...
#
#                                                   Title  sv_score
# 0     \r\n                Wal-Mart eliminates more c...    0.0258
# 1     \r\n                Japanese retailer Aeon pla...   -0.8176
# 2     \r\n                Food fight: To beat China ...    0.9906
# 3     \r\n                Trump's message to bankers...    0.9169
# 4     \r\n                U.S. trade group hacked wi...   -0.0018
# 5     \r\n                トランプ米大統領、金融規制改革法改正を再表明　財界と...    0.0000
# 6     Target and Bed Bath and Beyond Could Be Due fo...    0.6258
# 7     Wal-Mart reportedly cutting hundreds of jobs t...   -0.9136
# 8     Nearly every American spent money at Wal-Mart ...    0.9521
# 9     Amazon stock upgraded on its Prime program, gr...    0.9648
# ...                                                 ...       ...
# 1149  \r\n      \r\n    Better Buy: Wal-Mart Stores ...    0.9951
# 1150  \r\n      \r\n    These 8 Retailers Are Actual...    0.9912
# 1151  \r\n      \r\n    Amazon Fresh Pickup Is a Tou...    0.9948
# 1152  \r\n      \r\n    Why Amazon Is So Focused on ...    0.9982
# 1153  \r\n      \r\n    The King of Beers Joins the ...    0.9960
# 1154  \r\n      \r\n    The Next Stock Warren Buffet...    0.9969
# 1155  \r\n      \r\n    After Souq.com Purchase, Wil...    0.9980
# 1156  \r\n      \r\n    Is Amazon Following Microsof...    0.9934
# 1157  Yale fund chief reveals truth about hedge fund...    0.9892
# 1158  Here’s Draghi’s 4-point checklist for when it’...    0.8481
#
# [1151 rows x 7 columns]

# %%
df.to_csv('{}Processed.csv'.format(folderName))
