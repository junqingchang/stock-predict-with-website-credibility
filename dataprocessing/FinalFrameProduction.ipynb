# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../scoredSelected/googlescored.csv', index_col=False)
iterations = df.shape[0]

# %%
df
# Out:
#           Date     Open  Delta  FractionalIncrease      High       Low  \
# 0   2016-11-17   782.50 -27.50           -0.033951   810.060   743.590
# 1   2016-11-25   782.61   0.11            0.000141   793.770   772.650
# 2   2016-12-01   778.55  -4.06           -0.005188   799.740   773.145
# 3   2016-12-08   792.95  14.40            0.018496   792.000   753.360
# 4   2016-12-15   817.36  24.41            0.030784   824.300   787.905
# 5   2016-12-22   809.10  -8.26           -0.010106   823.000   804.500
# 6   2016-12-29   802.33  -6.77           -0.008367   816.000   802.440
# 7   2017-01-05   807.50   5.17            0.006444   813.430   789.620
# 8   2017-01-12   828.38  20.88            0.025858   830.430   805.920
# 9   2017-01-19   829.00   0.62            0.000748   834.650   821.010
# 10  2017-01-26   859.05  30.05            0.036248   858.794   823.960
# 11  2017-02-02   815.00 -44.05           -0.051278   867.000   812.250
# ...

# %%
df1 = pd.read_csv('../scoredSelected/googlescored.csv', index_col=False)
df2 = pd.read_csv('../scoredSelected/walmartscored.csv', index_col=False)
# df3 = pd.read_csv('../scoredSelected/attscored.csv', index_col=False)
df4 = pd.read_csv('../scoredSelected/exxonscored.csv', index_col=False)
df5 = pd.read_csv('../scoredSelected/unitedhealthscored.csv', index_col=False)
df6 = pd.read_csv('../scoredSelected/verizonscored.csv', index_col=False)
df7 = pd.read_csv('../scoredSelected/wellsfargoscored.csv', index_col=False)

for i in range(iterations):
    reuter_count = 0
    reuter_score = None
    if not pd.isna(df1.loc[i, "reuter_cumu"]):
        reuter_count += 1
        if reuter_score:
            reuter_score += df1.loc[i, "reuter_cumu"]
        else:
            reuter_score = df1.loc[i, "reuter_cumu"]

    if not pd.isna(df2.loc[i, "reuter_cumu"]):
        reuter_count += 1
        if reuter_score:
            reuter_score += df2.loc[i, "reuter_cumu"]
        else:
            reuter_score = df2.loc[i, "reuter_cumu"]

#     if not pd.isna(df3.loc[i, "reuter_cumu"]):
#         reuter_count += 1
#         if reuter_score:
#             reuter_score += df3.loc[i, "reuter_cumu"]
#         else:
#             reuter_score = df3.loc[i, "reuter_cumu"]

    if not pd.isna(df4.loc[i, "reuter_cumu"]):
        reuter_count += 1
        if reuter_score:
            reuter_score += df4.loc[i, "reuter_cumu"]
        else:
            reuter_score = df4.loc[i, "reuter_cumu"]

    if not pd.isna(df5.loc[i, "reuter_cumu"]):
        reuter_count += 1
        if reuter_score:
            reuter_score += df5.loc[i, "reuter_cumu"]
        else:
            reuter_score = df5.loc[i, "reuter_cumu"]

    if not pd.isna(df6.loc[i, "reuter_cumu"]):
        reuter_count += 1
        if reuter_score:
            reuter_score += df6.loc[i, "reuter_cumu"]
        else:
            reuter_score = df6.loc[i, "reuter_cumu"]

    if not pd.isna(df7.loc[i, "reuter_cumu"]):
        reuter_count += 1
        if reuter_score:
            reuter_score += df7.loc[i, "reuter_cumu"]
        else:
            reuter_score = df7.loc[i, "reuter_cumu"]
            
    if reuter_score:
        df1.loc[i, "ReuterCredit"] = reuter_score/reuter_count
        df2.loc[i, "ReuterCredit"] = reuter_score/reuter_count
#         df3.loc[i, "ReuterCredit"] = reuter_score/reuter_count
        df4.loc[i, "ReuterCredit"] = reuter_score/reuter_count
        df5.loc[i, "ReuterCredit"] = reuter_score/reuter_count
        df6.loc[i, "ReuterCredit"] = reuter_score/reuter_count
        df7.loc[i, "ReuterCredit"] = reuter_score/reuter_count
    else:
        df1.loc[i, "ReuterCredit"] = None
        df2.loc[i, "ReuterCredit"] = None
#         df3.loc[i, "ReuterCredit"] = None
        df4.loc[i, "ReuterCredit"] = None
        df5.loc[i, "ReuterCredit"] = None
        df6.loc[i, "ReuterCredit"] = None
        df7.loc[i, "ReuterCredit"] = None
    
    fool_count = 0
    fool_score = None
    if not pd.isna(df1.loc[i, "fool_cumu"]):
        fool_count += 1
        if fool_score:
            fool_score += df1.loc[i, "fool_cumu"]
        else:
            fool_score = df1.loc[i, "fool_cumu"]

    if not pd.isna(df2.loc[i, "fool_cumu"]):
        fool_count += 1
        if fool_score:
            fool_score += df2.loc[i, "fool_cumu"]
        else:
            fool_score = df2.loc[i, "fool_cumu"]

#     if not pd.isna(df3.loc[i, "fool_cumu"]):
#         fool_count += 1
#         if fool_score:
#             fool_score += df3.loc[i, "fool_cumu"]
#         else:
#             fool_score = df3.loc[i, "fool_cumu"]

    if not pd.isna(df4.loc[i, "fool_cumu"]):
        fool_count += 1
        if fool_score:
            fool_score += df4.loc[i, "fool_cumu"]
        else:
            fool_score = df4.loc[i, "fool_cumu"]

    if not pd.isna(df5.loc[i, "fool_cumu"]):
        fool_count += 1
        if fool_score:
            fool_score += df5.loc[i, "fool_cumu"]
        else:
            fool_score = df5.loc[i, "fool_cumu"]

    if not pd.isna(df6.loc[i, "fool_cumu"]):
        fool_count += 1
        if fool_score:
            fool_score += df6.loc[i, "fool_cumu"]
        else:
            fool_score = df6.loc[i, "fool_cumu"]

    if not pd.isna(df7.loc[i, "fool_cumu"]):
        fool_count += 1
        if fool_score:
            fool_score += df7.loc[i, "fool_cumu"]
        else:
            fool_score = df7.loc[i, "fool_cumu"]
            
    if fool_score:
        df1.loc[i, "FoolCredit"] = fool_score/fool_count
        df2.loc[i, "FoolCredit"] = fool_score/fool_count
#         df3.loc[i, "FoolCredit"] = fool_score/fool_count
        df4.loc[i, "FoolCredit"] = fool_score/fool_count
        df5.loc[i, "FoolCredit"] = fool_score/fool_count
        df6.loc[i, "FoolCredit"] = fool_score/fool_count
        df7.loc[i, "FoolCredit"] = fool_score/fool_count
    else:
        df1.loc[i, "FoolCredit"] = None
        df2.loc[i, "FoolCredit"] = None
#         df3.loc[i, "FoolCredit"] = None
        df4.loc[i, "FoolCredit"] = None
        df5.loc[i, "FoolCredit"] = None
        df6.loc[i, "FoolCredit"] = None
        df7.loc[i, "FoolCredit"] = None
    
    invest_count = 0
    invest_score = None
    if not pd.isna(df1.loc[i, "invest_cumu"]):
        invest_count += 1
        if invest_score:
            invest_score += df1.loc[i, "invest_cumu"]
        else:
            invest_score = df1.loc[i, "invest_cumu"]

    if not pd.isna(df2.loc[i, "invest_cumu"]):
        invest_count += 1
        if invest_score:
            invest_score += df2.loc[i, "invest_cumu"]
        else:
            invest_score = df2.loc[i, "invest_cumu"]

#     if not pd.isna(df3.loc[i, "invest_cumu"]):
#         invest_count += 1
#         if invest_score:
#             invest_score += df3.loc[i, "invest_cumu"]
#         else:
#             invest_score = df3.loc[i, "invest_cumu"]

    if not pd.isna(df4.loc[i, "invest_cumu"]):
        invest_count += 1
        if invest_score:
            invest_score += df4.loc[i, "invest_cumu"]
        else:
            invest_score = df4.loc[i, "invest_cumu"]

    if not pd.isna(df5.loc[i, "invest_cumu"]):
        invest_count += 1
        if invest_score:
            invest_score += df5.loc[i, "invest_cumu"]
        else:
            invest_score = df5.loc[i, "invest_cumu"]

    if not pd.isna(df6.loc[i, "invest_cumu"]):
        invest_count += 1
        if invest_score:
            invest_score += df6.loc[i, "invest_cumu"]
        else:
            invest_score = df6.loc[i, "invest_cumu"]

    if not pd.isna(df7.loc[i, "invest_cumu"]):
        invest_count += 1
        if invest_score:
            invest_score += df7.loc[i, "invest_cumu"]
        else:
            invest_score = df7.loc[i, "invest_cumu"]
            
    if invest_score:
        df1.loc[i, "InvestCredit"] = invest_score/invest_count
        df2.loc[i, "InvestCredit"] = invest_score/invest_count
#         df3.loc[i, "InvestCredit"] = invest_score/invest_count
        df4.loc[i, "InvestCredit"] = invest_score/invest_count
        df5.loc[i, "InvestCredit"] = invest_score/invest_count
        df6.loc[i, "InvestCredit"] = invest_score/invest_count
        df7.loc[i, "InvestCredit"] = invest_score/invest_count
    else:
        df1.loc[i, "InvestCredit"] = None
        df2.loc[i, "InvestCredit"] = None
#         df3.loc[i, "InvestCredit"] = None
        df4.loc[i, "InvestCredit"] = None
        df5.loc[i, "InvestCredit"] = None
        df6.loc[i, "InvestCredit"] = None
        df7.loc[i, "InvestCredit"] = None
    
    cnbc_count = 0
    cnbc_score = None
    if not pd.isna(df1.loc[i, "cnbc_cumu"]):
        cnbc_count += 1
        if cnbc_score:
            cnbc_score += df1.loc[i, "cnbc_cumu"]
        else:
            cnbc_score = df1.loc[i, "cnbc_cumu"]

    if not pd.isna(df2.loc[i, "cnbc_cumu"]):
        cnbc_count += 1
        if cnbc_score:
            cnbc_score += df2.loc[i, "cnbc_cumu"]
        else:
            cnbc_score = df2.loc[i, "cnbc_cumu"]

#     if not pd.isna(df3.loc[i, "cnbc_cumu"]):
#         cnbc_count += 1
#         if cnbc_score:
#             cnbc_score += df3.loc[i, "cnbc_cumu"]
#         else:
#             cnbc_score = df3.loc[i, "cnbc_cumu"]

    if not pd.isna(df4.loc[i, "cnbc_cumu"]):
        cnbc_count += 1
        if cnbc_score:
            cnbc_score += df4.loc[i, "cnbc_cumu"]
        else:
            cnbc_score = df4.loc[i, "cnbc_cumu"]

    if not pd.isna(df5.loc[i, "cnbc_cumu"]):
        cnbc_count += 1
        if cnbc_score:
            cnbc_score += df5.loc[i, "cnbc_cumu"]
        else:
            cnbc_score = df5.loc[i, "cnbc_cumu"]

    if not pd.isna(df6.loc[i, "cnbc_cumu"]):
        cnbc_count += 1
        if cnbc_score:
            cnbc_score += df6.loc[i, "cnbc_cumu"]
        else:
            cnbc_score = df6.loc[i, "cnbc_cumu"]

    if not pd.isna(df7.loc[i, "cnbc_cumu"]):
        cnbc_count += 1
        if cnbc_score:
            cnbc_score += df7.loc[i, "cnbc_cumu"]
        else:
            cnbc_score = df7.loc[i, "cnbc_cumu"]
            
    if cnbc_score:
        df1.loc[i, "CnbcCredit"] = cnbc_score/cnbc_count
        df2.loc[i, "CnbcCredit"] = cnbc_score/cnbc_count
#         df3.loc[i, "CnbcCredit"] = cnbc_score/cnbc_count
        df4.loc[i, "CnbcCredit"] = cnbc_score/cnbc_count
        df5.loc[i, "CnbcCredit"] = cnbc_score/cnbc_count
        df6.loc[i, "CnbcCredit"] = cnbc_score/cnbc_count
        df7.loc[i, "CnbcCredit"] = cnbc_score/cnbc_count
    else:
        df1.loc[i, "CnbcCredit"] = None
        df2.loc[i, "CnbcCredit"] = None
#         df3.loc[i, "CnbcCredit"] = None
        df4.loc[i, "CnbcCredit"] = None
        df5.loc[i, "CnbcCredit"] = None
        df6.loc[i, "CnbcCredit"] = None
        df7.loc[i, "CnbcCredit"] = None
    
    market_count = 0
    market_score = None
    if not pd.isna(df1.loc[i, "market_cumu"]):
        market_count += 1
        if market_score:
            market_score += df1.loc[i, "market_cumu"]
        else:
            market_score = df1.loc[i, "market_cumu"]

    if not pd.isna(df2.loc[i, "market_cumu"]):
        market_count += 1
        if market_score:
            market_score += df2.loc[i, "market_cumu"]
        else:
            market_score = df2.loc[i, "market_cumu"]

#     if not pd.isna(df3.loc[i, "market_cumu"]):
#         market_count += 1
#         if market_score:
#             market_score += df3.loc[i, "market_cumu"]
#         else:
#             market_score = df3.loc[i, "market_cumu"]

    if not pd.isna(df4.loc[i, "market_cumu"]):
        market_count += 1
        if market_score:
            market_score += df4.loc[i, "market_cumu"]
        else:
            market_score = df4.loc[i, "market_cumu"]

    if not pd.isna(df5.loc[i, "market_cumu"]):
        market_count += 1
        if market_score:
            market_score += df5.loc[i, "market_cumu"]
        else:
            market_score = df5.loc[i, "market_cumu"]

    if not pd.isna(df6.loc[i, "market_cumu"]):
        market_count += 1
        if market_score:
            market_score += df6.loc[i, "market_cumu"]
        else:
            market_score = df6.loc[i, "market_cumu"]

    if not pd.isna(df7.loc[i, "market_cumu"]):
        market_count += 1
        if market_score:
            market_score += df7.loc[i, "market_cumu"]
        else:
            market_score = df7.loc[i, "market_cumu"]
            
    if market_score:
        df1.loc[i, "MarketCredit"] = market_score/market_count
        df2.loc[i, "MarketCredit"] = market_score/market_count
#         df3.loc[i, "MarketCredit"] = market_score/market_count
        df4.loc[i, "MarketCredit"] = market_score/market_count
        df5.loc[i, "MarketCredit"] = market_score/market_count
        df6.loc[i, "MarketCredit"] = market_score/market_count
        df7.loc[i, "MarketCredit"] = market_score/market_count
    else:
        df1.loc[i, "MarketCredit"] = None
        df2.loc[i, "MarketCredit"] = None
#         df3.loc[i, "MarketCredit"] = None
        df4.loc[i, "MarketCredit"] = None
        df5.loc[i, "MarketCredit"] = None
        df6.loc[i, "MarketCredit"] = None
        df7.loc[i, "MarketCredit"] = None

# %%
pd.set_option('display.max_columns', 100)
df1
# Out:
#           Date     Open  Delta  FractionalIncrease      High       Low  \
# 0   2016-11-17   782.50 -27.50           -0.033951   810.060   743.590
# 1   2016-11-25   782.61   0.11            0.000141   793.770   772.650
# 2   2016-12-01   778.55  -4.06           -0.005188   799.740   773.145
# 3   2016-12-08   792.95  14.40            0.018496   792.000   753.360
# 4   2016-12-15   817.36  24.41            0.030784   824.300   787.905
# 5   2016-12-22   809.10  -8.26           -0.010106   823.000   804.500
# 6   2016-12-29   802.33  -6.77           -0.008367   816.000   802.440
# 7   2017-01-05   807.50   5.17            0.006444   813.430   789.620
# 8   2017-01-12   828.38  20.88            0.025858   830.430   805.920
# 9   2017-01-19   829.00   0.62            0.000748   834.650   821.010
# 10  2017-01-26   859.05  30.05            0.036248   858.794   823.960
# 11  2017-02-02   815.00 -44.05           -0.051278   867.000   812.250
# ...

# %%
combine = pd.concat([df1,df2,df4,df5,df6,df7])

# %%
output = combine[["Open", "Delta", "FractionalIncrease", "High", "Low", "Positive", "ReuterCredit", "reuter_score", "InvestCredit", "invest_score", "FoolCredit", "fool_score", "CnbcCredit", "cnbc_score", "MarketCredit", 'market_score']].copy()

# %%
output = output.loc[(output["ReuterCredit"] > 0) & (output["MarketCredit"] > 0) & (output["FoolCredit"] > 0) & (output["CnbcCredit"] > 0) & (output["InvestCredit"] > 0)]

# %%
output.fillna(0)
# Out:
#         Open   Delta  FractionalIncrease      High      Low  Positive  \
# 2    778.550  -4.060           -0.005188   799.740  773.145     False
# 3    792.950  14.400            0.018496   792.000  753.360      True
# 4    817.360  24.410            0.030784   824.300  787.905      True
# 5    809.100  -8.260           -0.010106   823.000  804.500     False
# 6    802.330  -6.770           -0.008367   816.000  802.440     False
# 7    807.500   5.170            0.006444   813.430  789.620      True
# 8    828.380  20.880            0.025858   830.430  805.920      True
# 9    829.000   0.620            0.000748   834.650  821.010      True
# 10   859.050  30.050            0.036248   858.794  823.960      True
# 11   815.000 -44.050           -0.051278   867.000  812.250     False
# 12   831.730  16.730            0.020528   834.250  812.051      True
# 13   838.500   6.770            0.008140   842.000  826.500      True
# ...

# %%
output.to_csv("../finaldata.csv", index = False)

# %%
# Graphing
df1 = df1.loc[(df1["ReuterCredit"] > 0) & (df1["MarketCredit"] > 0) & (df1["FoolCredit"] > 0) & (df1["CnbcCredit"] > 0) & (df1["InvestCredit"] > 0)]

# %%
import matplotlib.pyplot as plt
def splitter(date):
    return date.split("-")[1]
df1["Year"] = df1["Date"].apply(splitter)
df1
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#           Date     Open  Delta  FractionalIncrease      High       Low  \
# 2   2016-12-01   778.55  -4.06           -0.005188   799.740   773.145
# 3   2016-12-08   792.95  14.40            0.018496   792.000   753.360
# 4   2016-12-15   817.36  24.41            0.030784   824.300   787.905
# 5   2016-12-22   809.10  -8.26           -0.010106   823.000   804.500
# 6   2016-12-29   802.33  -6.77           -0.008367   816.000   802.440
# 7   2017-01-05   807.50   5.17            0.006444   813.430   789.620
# ...

# %%
df1.to_csv("graphplot.csv", index=False)
